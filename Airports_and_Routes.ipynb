# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Fazendo merge entre os datasets airportsNew e routes.

# %%
df_airports = pd.read_csv('/content/airportsNew.csv')

# %%
df_airports.head(10)
# Out:
#    ID                                 Airport Name          City  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
# 5   6                  Wewak International Airport         Wewak
# 6   7                           Narsarsuaq Airport  Narssarssuaq
# 7   8                      Godthaab / Nuuk Airport      Godthaab
# 8   9                        Kangerlussuaq Airport   Sondrestrom
# 9  10                               Thule Air Base         Thule
#
#             Country IATA Code ICAO Code   Latitude   Longitude  Altitude  \
# 0  Papua New Guinea       GKA      AYGA  -6.081690  145.391998      5282
# 1  Papua New Guinea       MAG      AYMD  -5.207080  145.789001        20
# 2  Papua New Guinea       HGU      AYMH  -5.826790  144.296005      5388
# 3  Papua New Guinea       LAE      AYNZ  -6.569803  146.725977       239
# 4  Papua New Guinea       POM      AYPY  -9.443380  147.220001       146
# 5  Papua New Guinea       WWK      AYWK  -3.583830  143.669006        19
# 6         Greenland       UAK      BGBW  61.160500  -45.425999       112
# 7         Greenland       GOH      BGGH  64.190903  -51.678101       283
# 8         Greenland       SFJ      BGSF  67.012222  -50.711603       165
# 9         Greenland       THU      BGTL  76.531197  -68.703201       251
#
#   Timezone Offset DST              Timezone     Type       Source
# 0              10   U  Pacific/Port_Moresby  airport  OurAirports
# 1              10   U  Pacific/Port_Moresby  airport  OurAirports
# 2              10   U  Pacific/Port_Moresby  airport  OurAirports
# 3              10   U  Pacific/Port_Moresby  airport  OurAirports
# 4              10   U  Pacific/Port_Moresby  airport  OurAirports
# 5              10   U  Pacific/Port_Moresby  airport  OurAirports
# 6              -3   E       America/Godthab  airport  OurAirports
# 7              -3   E       America/Godthab  airport  OurAirports
# 8              -3   E       America/Godthab  airport  OurAirports
# 9              -4   E         America/Thule  airport  OurAirports

# %%
df_airports["Latitude"] = df_airports["Latitude"].round(4)
df_airports["Longitude"] = df_airports["Longitude"].round(4)

# %%
df_airports.head(10)
# Out:
#    ID                                 Airport Name          City  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
# 5   6                  Wewak International Airport         Wewak
# 6   7                           Narsarsuaq Airport  Narssarssuaq
# 7   8                      Godthaab / Nuuk Airport      Godthaab
# 8   9                        Kangerlussuaq Airport   Sondrestrom
# 9  10                               Thule Air Base         Thule
#
#             Country IATA Code ICAO Code  Latitude  Longitude  Altitude  \
# 0  Papua New Guinea       GKA      AYGA   -6.0817   145.3920      5282
# 1  Papua New Guinea       MAG      AYMD   -5.2071   145.7890        20
# 2  Papua New Guinea       HGU      AYMH   -5.8268   144.2960      5388
# 3  Papua New Guinea       LAE      AYNZ   -6.5698   146.7260       239
# 4  Papua New Guinea       POM      AYPY   -9.4434   147.2200       146
# 5  Papua New Guinea       WWK      AYWK   -3.5838   143.6690        19
# 6         Greenland       UAK      BGBW   61.1605   -45.4260       112
# 7         Greenland       GOH      BGGH   64.1909   -51.6781       283
# 8         Greenland       SFJ      BGSF   67.0122   -50.7116       165
# 9         Greenland       THU      BGTL   76.5312   -68.7032       251
#
#   Timezone Offset DST              Timezone     Type       Source
# 0              10   U  Pacific/Port_Moresby  airport  OurAirports
# 1              10   U  Pacific/Port_Moresby  airport  OurAirports
# 2              10   U  Pacific/Port_Moresby  airport  OurAirports
# 3              10   U  Pacific/Port_Moresby  airport  OurAirports
# 4              10   U  Pacific/Port_Moresby  airport  OurAirports
# 5              10   U  Pacific/Port_Moresby  airport  OurAirports
# 6              -3   E       America/Godthab  airport  OurAirports
# 7              -3   E       America/Godthab  airport  OurAirports
# 8              -3   E       America/Godthab  airport  OurAirports
# 9              -4   E         America/Thule  airport  OurAirports

# %%
df_routes = pd.read_csv('/content/routes.csv', sep=';')

# %%
df_routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67663 entries, 0 to 67662
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CodigoCompanhiaAerea  67663 non-null  object
#  1   NumeroVoo             67663 non-null  object
#  2   AeroportoPartida      67663 non-null  object
#  3   ID_AeroportoPartida   67663 non-null  object
#  4   AeroportoChegada      67663 non-null  object
#  5   ID_AeroportoChegada   67663 non-null  object
#  6   CodeShare             67663 non-null  object
#  7   Paradas               67663 non-null  int64
#  8   Equipamento           67645 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 4.6+ MB

# %%
# Renomear as colunas do DataFrame df_routes com nomes apropriados
df_routes.columns = [
    'CodigoCompanhiaAerea', 'NumeroVoo', 'AeroportoPartida', 'ID_AeroportoPartida',
    'AeroportoChegada', 'ID_AeroportoChegada', 'CodeShare', 'Paradas', 'Equipamento'
]

# Merge do DataFrame de rotas com o de aeroportos para Aeroporto de Partida
df_routes_merged_departure = df_routes.merge(
    df_airports[['Aeroporto', 'Country', 'Cidade', 'Latitude', 'Longitude']],
    left_on='AeroportoPartida',
    right_on='Aeroporto',
    how='left'
).drop(columns=['Aeroporto'])

# Renomear as colunas adicionadas para diferenciar Partida e Chegada
df_routes_merged_departure = df_routes_merged_departure.rename(columns={
    'Cidade': 'Cidade_Partida',
    'Latitude': 'Latitude_Partida',
    'Longitude': 'Longitude_Partida',
    'Country': 'PaisPartida'
})

# Merge do DataFrame resultante com o de aeroportos para Aeroporto de Chegada
df_routes_merged = df_routes_merged_departure.merge(
    df_airports[['Aeroporto', 'Country', 'Cidade', 'Latitude', 'Longitude']],
    left_on='AeroportoChegada',
    right_on='Aeroporto',
    how='left'
).drop(columns=['Aeroporto'])

# Renomear as colunas adicionadas para diferenciar Partida e Chegada
df_routes_merged = df_routes_merged.rename(columns={
    'Cidade': 'Cidade_Chegada',
    'Latitude': 'Latitude_Chegada',
    'Longitude': 'Longitude_Chegada',
    'Country': 'PaisChegada'
})

# Salvar o DataFrame resultante em um novo arquivo CSV
output_path_corrected = 'routes_with_airports_corrected.csv'
df_routes_merged.to_csv(output_path_corrected, index=False)

# %% [markdown]
# ## Adicionando a distância entre as cidades

# %%
# Função para calcular a distância entre dois pontos usando a fórmula de Haversine
def haversine(lat1, lon1, lat2, lon2):
    # Converter de graus para radianos
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    # Diferenças das coordenadas
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    # Fórmula de Haversine
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))

    # Raio da Terra em quilômetros
    r = 6371
    return c * r

# %%
# Aplicar a função ao dataset carregado anteriormente
df_routes_merged['Distancia_km'] = df_routes_merged.apply(
    lambda row: haversine(row['Latitude_Partida'], row['Longitude_Partida'], row['Latitude_Chegada'], row['Longitude_Chegada']),
    axis=1
)

# %%
df_routes_merged["Distancia_km"]= df_routes_merged["Distancia_km"].round(0)

# %%
df_routes_merged.head(10)
# Out:
#   CodigoCompanhiaAerea NumeroVoo AeroportoPartida ID_AeroportoPartida  \
# 0                   2B       410              AER                2965
# 1                   2B       410              ASF                2966
# 2                   2B       410              ASF                2966
# 3                   2B       410              CEK                2968
# 4                   2B       410              CEK                2968
# 5                   2B       410              DME                4029
# 6                   2B       410              DME                4029
# 7                   2B       410              DME                4029
# 8                   2B       410              DME                4029
# 9                   2B       410              EGO                6156
#
#   AeroportoChegada ID_AeroportoChegada CodeShare  Paradas Equipamento  \
# 0              KZN                2990         N        0         CR2
# 1              KZN                2990         N        0         CR2
# 2              MRV                2962         N        0         CR2
# 3              KZN                2990         N        0         CR2
# 4              OVB                4078         N        0         CR2
# 5              KZN                2990         N        0         CR2
# 6              NBC                6969         N        0         CR2
# 7              TGK                  \N         N        0         CR2
# 8              UUA                6160         N        0         CR2
# 9              KGD                2952         N        0         CR2
#
#   PaisPartida Cidade_Partida  Latitude_Partida  Longitude_Partida PaisChegada  \
# 0      Russia          Sochi           43.4499            39.9566      Russia
# 1      Russia      Astrakhan           46.2833            48.0063      Russia
# 2      Russia      Astrakhan           46.2833            48.0063      Russia
# 3      Russia    Chelyabinsk           55.3058            61.5033      Russia
# 4      Russia    Chelyabinsk           55.3058            61.5033      Russia
# 5      Russia         Moscow           55.4088            37.9063      Russia
# 6      Russia         Moscow           55.4088            37.9063      Russia
# 7      Russia         Moscow           55.4088            37.9063         NaN
# 8      Russia         Moscow           55.4088            37.9063      Russia
# 9      Russia       Belgorod           50.6438            36.5901      Russia
#
#     Cidade_Chegada  Latitude_Chegada  Longitude_Chegada  Distancia_km
# 0            Kazan           55.6062            49.2787        1507.0
# 1            Kazan           55.6062            49.2787        1040.0
# 2  Mineralnye Vody           44.2251            43.0819         448.0
# 3            Kazan           55.6062            49.2787         771.0
# 4      Novosibirsk           55.0126            82.6507        1339.0
# 5            Kazan           55.6062            49.2787         716.0
# 6      Nizhnekamsk           55.5647            52.0925         892.0
# 7              NaN               NaN                NaN           NaN
# 8          Bugulma           54.6400            52.8017         951.0
# 9      Kaliningrad           54.8900            20.5926        1172.0

# %%
df_routes_merged.to_csv("routes_with_distance.csv", index=False)
